# %% [markdown]
# # Extra credit
# ## EC1. Provide your own implementation of a squared error loss function, and run an experiment to compare it to cross entropy. What do you find?

# %%
def loss_SE(y_true, y_pred):
  loss = np.sum((y_true - y_pred)**2) * 小于会出错，溢出

# %%
y_train[0:5], y_test[0:5], y_train[0:5]-y_test[0:5]

# %%
np.sum((y_test[2:5]-y_train[2:5])**2)

# %%
type(y_train[:])

# %% [markdown]
# ## EC2. Provide your own implementation of a Dense layer.

# %% [markdown]
# ## EC3. ​Visualize the learned weights.
