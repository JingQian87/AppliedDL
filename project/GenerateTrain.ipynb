# %% [markdown]
# # 4998 Applied Deep Learning Project
# ## Detect Cancer Metastases on Pathology Images
#
# Jing Qian (jq2282)

# %% [markdown]
# # STEP 1. IMAGE PROCESSING
#
# * Read this paper to understand their approach https://arxiv.org/pdf/1703.02442.pdf
# * Start small (use a single slide, at the lowest available zoom level - the effective resolution should be on the order of 1,000 by 1,000 pixels).
# * Write code to slide a window across the slide. Extract patches and labels (using the tissue mask).

# %% [markdown]
# ## 1.1. Import data

# %%
# Install the OpenSlide C library and Python bindings
# !apt-get install openslide-tools
# !pip install openslide-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# openslide-tools is already the newest version (3.4.1+dfsg-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Requirement already satisfied: openslide-python in /usr/local/lib/python3.6/dist-packages (1.1.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from openslide-python) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->openslide-python) (0.46)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from openslide import open_slide, __library_version__ as openslide_version
import os
from PIL import Image
from skimage.color import rgb2gray

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# list all the slides provided by professor
# !ls '/content/drive/My Drive/project-adl/slides'
# Out:
# tumor_001_mask.tif  tumor_019.tif	tumor_064_mask.tif  tumor_091.tif
# tumor_001.tif	    tumor_023_mask.tif	tumor_064.tif	    tumor_094_mask.tif
# tumor_002_mask.tif  tumor_023.tif	tumor_075_mask.tif  tumor_094.tif
# tumor_002.tif	    tumor_031_mask.tif	tumor_075.tif	    tumor_096_mask.tif
# tumor_005_mask.tif  tumor_031.tif	tumor_078_mask.tif  tumor_096.tif
# tumor_005.tif	    tumor_035_mask.tif	tumor_078.tif	    tumor_101_mask.tif
# tumor_012_mask.tif  tumor_035.tif	tumor_081_mask.tif  tumor_101.tif
# tumor_012.tif	    tumor_057_mask.tif	tumor_081.tif	    tumor_110_mask.tif
# tumor_016_mask.tif  tumor_057.tif	tumor_084_mask.tif  tumor_110.tif
# tumor_016.tif	    tumor_059_mask.tif	tumor_084.tif
# tumor_019_mask.tif  tumor_059.tif	tumor_091_mask.tif

# %% [markdown]
# 从上面可以看到完整的图像有21个，tumor_038和tumor_099有问题，不用。如果是全部都用于train/test，就17个train, 4个test。从1 vs 1开始

# %%
train_list = ['005','012','016','019','023','031','035','057','059',
              '064','075','078','081','084','091','094','096']
test_list = ['001','002','101','110']
slide_list = train_list + test_list
print(slide_list)
# Out:
# ['005', '012', '016', '019', '023', '031', '035', '057', '059', '064', '075', '078', '081', '084', '091', '094', '096', '001', '002', '101', '110']

# %% [markdown]
# ## 1.2. Generate images of all slides at level 7

# %%
#slide_id='091'
for slide_id in slides_list:
  slide_path = os.path.join(total_path,'tumor_%s.tif' %slide_id)
  tumor_mask_path = os.path.join(total_path,'tumor_%s_mask.tif' %slide_id)

  slide = open_slide(slide_path)
  print("Read WSI from %s includes %d levels" %(slide_path,len(slide.level_dimensions)))
  tumor_mask = open_slide(tumor_mask_path)
  slide_image = read_slide(slide, 
                         x=0, 
                         y=0, 
                         level=7, 
                         width=slide.level_dimensions[7][0], 
                         height=slide.level_dimensions[7][1])
  mask_image = read_slide(tumor_mask, 
                        x=0, 
                        y=0, 
                        level=7, 
                        width=slide.level_dimensions[7][0], 
                        height=slide.level_dimensions[7][1])[:,:,0]
  fig = plt.figure(figsize=(10,10), dpi=100)
  plt.imshow(slide_image)
  filename = 'drive/My Drive/project-adl/image_lev7/image_lev7_%s.png' %slide_id
  plt.imshow(mask_image, cmap='jet', alpha=0.5) 
  fig.savefig(filename)

# %% [markdown]
# ## 1.3. Generate training patches and corresponding labels
#
# Sample from only center 10%-90% region to avoid boundary effect.

# %% [markdown]
# ### Start with one slide

# %% [markdown]
# ###  General Params

# %%
# Set patches as 299*299 in lev3/4, check center 128*128 at lev 3 for labeling.
input_size = 299
tumor_check_size = 128
bound = (input_size - 1)/2

# %%
down_factor = dict()
for i in range(8):
  down_factor[i] = 2**i
print(down_factor)
# Out:
# {0: 1, 1: 2, 2: 4, 3: 8, 4: 16, 5: 32, 6: 64, 7: 128}

# %%
total_path = '/content/drive/My Drive/project-adl/slides'

# %%
# See https://openslide.org/api/python/#openslide.OpenSlide.read_region
# Note: x,y coords are with respect to level 0.
# Read a region from the slide
# Return a numpy RBG array
def read_slide(slide, x, y, level, width, height, as_float=False):
    #print('1')
    im = slide.read_region((x,y), level, (width, height))
    #print('2')
    im = im.convert('RGB') # drop the alpha channel
    #print('3')
    if as_float:
        im = np.asarray(im, dtype=np.float32)
    else:
        im = np.asarray(im)
    assert im.shape == (height, width, 3)
    return im

# %%
# As mentioned in class, we can improve efficiency by ignoring non-tissue areas 
# of the slide. We'll find these by looking for all gray regions.
def find_tissue_pixels(image, intensity=0.8):
    im_gray = rgb2gray(image)
    assert im_gray.shape == (image.shape[0], image.shape[1])
    indices = np.where(im_gray <= intensity)
    return zip(indices[0], indices[1])

# %%
## Test the boundary of defined tissue region and found boundary effects
# xmin, xmax, ymin, ymax = 0, 0, 0, 0
# for i in tissue_pixels:
#   xmin = min(i[0], xmin) 
#   xmax = max(i[0], xmax)#x correspond to dimention[1]
#   ymin = min(i[1], ymin)
#   ymax = max(i[1], ymax)

# print(xmin, xmax, ymin, ymax)
# print('canvas size:', slide.level_dimensions[ilevel])
# Out:
# 0 3359 0 3839
# canvas size: (3840, 3360)

# %%
def generate_train(slide_id, nclass, ilevel=3, tissue_intensity=0.5):
  slide_path = os.path.join(total_path,'tumor_%s.tif' %slide_id)
  tumor_mask_path = os.path.join(total_path,'tumor_%s_mask.tif' %slide_id)

  slide = open_slide(slide_path)
  print ("Read WSI from %s with width: %d, height: %d" % (slide_path, 
                                                          slide.level_dimensions[0][0], 
                                                          slide.level_dimensions[0][1]))

  tumor_mask = open_slide(tumor_mask_path)
  print ("Read tumor mask from %s" % (tumor_mask_path))

  print("Slide includes %d levels", len(slide.level_dimensions))
  for i in range(len(slide.level_dimensions)):
      print("Level %d, dimensions: %s downsample factor %d" % (i, 
                                                               slide.level_dimensions[i], 
                                                               slide.level_downsamples[i]))
      if i < 8:
        assert tumor_mask.level_dimensions[i][0] == slide.level_dimensions[i][0]
        assert tumor_mask.level_dimensions[i][1] == slide.level_dimensions[i][1]

  # Verify downsampling works as expected
  width, height = slide.level_dimensions[7]
  assert width * slide.level_downsamples[7] == slide.level_dimensions[0][0]
  assert height * slide.level_downsamples[7] == slide.level_dimensions[0][1]

  slide_image = read_slide(slide, 
                         x=0, 
                         y=0, 
                         level=ilevel, 
                         width=slide.level_dimensions[ilevel][0], 
                         height=slide.level_dimensions[ilevel][1])
  
  # Keep only tissue regions
  tissue_pixels = list(find_tissue_pixels(slide_image, intensity=tissue_intensity))
  #print('Dimension of Tissue_pixels:', np.shape(tissue_pixels))
  percent_tissue = len(tissue_pixels) / float(slide_image.shape[0] * slide_image.shape[0]) * 100
  print ("%d tissue_pixels pixels (%.1f percent of the image)" % (len(tissue_pixels), percent_tissue)) 
  
  train_0, train_1 = [], []
  while len(train_0) < nclass or len(train_1) < nclass:
    # Random sample a tissue pixel and generate a patch centered in this pixel
    width = slide.level_dimensions[ilevel][0]
    height = slide.level_dimensions[ilevel][1]
    while True:
      center = tissue_pixels[np.random.choice(np.shape(tissue_pixels)[0])]
      if center[0] > height*0.1 and center[0] < height*0.9:
        if center[1] > width*0.1 and center[1] < width*0.9:
          break
    print(center)

    # Expand a 299*299 patch around the center tissue
    ipatch = read_slide(slide, 
                       x=int(center[1]-bound)*down_factor[ilevel], #16 for level=4 
                       y=int(center[0]-bound)*down_factor[ilevel], 
                       level=ilevel, 
                       width=input_size, 
                       height=input_size)

    # Check whether the 128*128 center pixels have tumor
    ipixels = read_slide(tumor_mask,
                         x = int(center[1]-63)*down_factor[ilevel], 
                         y = int(center[0]-63)*down_factor[ilevel],
                         level = ilevel,
                         width = tumor_check_size,
                         height = tumor_check_size)[:,:,0]
    #plt.imshow(ipixels)

    ilabel = 0
    if np.any(ipixels) == 1:
      ilabel = 1
    print('The label for the patch is:', str(ilabel))
    if ilabel == 0:
      if len(train_0) < nclass:
        train_0.append(ipatch)
        print('train_0 add one patch and current have %d patches!' %len(train_0))
    else:
      if len(train_1) < nclass:
        train_1.append(ipatch)
        print('train_1 add one patch and current have %d patches!' %len(train_1))
        
  return train_0, train_1

# %% [markdown]
# From above, we could see that for figure, x-axis is horizontal with width while y-axis is vertical with height.
# However, the tissue_pixels is organized as following: the 0-element is the row from top to bottom, 1-element is the column from left to right, so 0-element is actually y coordinate and 1-element is actually x coordinate.
#
# I constrain the center of patch as tissue pixel with y > 0.1height and < 0.9height, x > 0.1width and <0.9width.

# %% [markdown]
# ## test separate sampling for label 0 and 1
#
# 直接在整体slide里改

# %%
def generate_train_2(slide_id, nclass, ilevel=3, tissue_intensity=0.5):
  slide_path = os.path.join(total_path,'tumor_%s.tif' %slide_id)
  tumor_mask_path = os.path.join(total_path,'tumor_%s_mask.tif' %slide_id)

  slide = open_slide(slide_path)
  print ("Read WSI from %s with width: %d, height: %d" % (slide_path, 
                                                          slide.level_dimensions[0][0], 
                                                          slide.level_dimensions[0][1]))

  tumor_mask = open_slide(tumor_mask_path)
  print ("Read tumor mask from %s" % (tumor_mask_path))

  print("Slide includes %d levels", len(slide.level_dimensions))
  for i in range(len(slide.level_dimensions)):
      print("Level %d, dimensions: %s downsample factor %d" % (i, 
                                                               slide.level_dimensions[i], 
                                                               slide.level_downsamples[i]))
      if i < 8:
        assert tumor_mask.level_dimensions[i][0] == slide.level_dimensions[i][0]
        assert tumor_mask.level_dimensions[i][1] == slide.level_dimensions[i][1]

  # Verify downsampling works as expected
  width, height = slide.level_dimensions[7]
  assert width * slide.level_downsamples[7] == slide.level_dimensions[0][0]
  assert height * slide.level_downsamples[7] == slide.level_dimensions[0][1]

  slide_image = read_slide(slide, 
                         x=int(slide.level_dimensions[ilevel][0]*0.1)*down_factor[ilevel], 
                         y=int(slide.level_dimensions[ilevel][1]*0.1)*down_factor[ilevel], 
                         level=ilevel, 
                         width=int(slide.level_dimensions[ilevel][0]*0.8), 
                         height=int(slide.level_dimensions[ilevel][1]*0.8))
  
  # Keep only tissue regions
  tissue_pixels = list(find_tissue_pixels(slide_image, intensity=tissue_intensity))
  #print('Dimension of Tissue_pixels:', np.shape(tissue_pixels))
  percent_tissue = len(tissue_pixels) / float(slide_image.shape[0] * slide_image.shape[0]) * 100
  print ("%d tissue_pixels pixels (%.1f percent of the image)" % (len(tissue_pixels), percent_tissue)) 
  
  train_0, train_1 = [], []
  
  # Generate label 0 class
  while len(train_0) < nclass:
    # Random sample a tissue pixel and generate a patch centered in this pixel
    center = tissue_pixels[np.random.choice(np.shape(tissue_pixels)[0])]
    print("[height, width] of sampled patch center:", center)
    
    # Check whether the 128*128 center pixels have tumor
    ipixels = read_slide(tumor_mask,
                         x = int(center[1]-63)*down_factor[ilevel], 
                         y = int(center[0]-63)*down_factor[ilevel],
                         level = ilevel,
                         width = tumor_check_size,
                         height = tumor_check_size)[:,:,0]
    #plt.imshow(ipixels)
    
    if np.any(ipixels) == 1:
      continue
    else:
      # Expand a 299*299 patch around the center tissue
      ipatch = read_slide(slide, 
                       x=int(center[1]-bound)*down_factor[ilevel], #16 for level=4 
                       y=int(center[0]-bound)*down_factor[ilevel], 
                       level=ilevel, 
                       width=input_size, 
                       height=input_size)
      train_0.append(ipatch)
      print('train_0 add one patch and current have %d patches!' %len(train_0))
        
  # generate label 1 class, sample only with tumor pixels
  mask_image = read_slide(tumor_mask,
                        x=int(slide.level_dimensions[ilevel][0]*0.1)*down_factor[ilevel], 
                        y=int(slide.level_dimensions[ilevel][1]*0.1)*down_factor[ilevel], 
                        level=ilevel, 
                        width=int(slide.level_dimensions[ilevel][0]*0.8), 
                        height=int(slide.level_dimensions[ilevel][1]*0.8))[:,:,0]
  tumor_id = np.transpose(np.nonzero(mask_image))
  while len(train_1) < nclass:
    center = tumor_id[np.random.choice(len(tumor_id))]
    center += [int(slide.level_dimensions[ilevel][1]*0.1), int(slide.level_dimensions[ilevel][0]*0.1)]

    # Check whether the 128*128 center pixels have tumor
    ipixels = read_slide(tumor_mask,
                         x = int(center[1]-63)*down_factor[ilevel], 
                         y = int(center[0]-63)*down_factor[ilevel],
                         level = ilevel,
                         width = tumor_check_size,
                         height = tumor_check_size)[:,:,0]
    if np.any(ipixels)==1: 
      # Expand a 299*299 patch around the center tissue
      ipatch = read_slide(slide, 
                       x=int(center[1]-bound)*down_factor[ilevel], #16 for level=4 
                       y=int(center[0]-bound)*down_factor[ilevel], 
                       level=ilevel, 
                       width=input_size, 
                       height=input_size)
      train_1.append(ipatch)
      print('train_1 add one patch and current have %d patches!' %len(train_1))
    else:
      print('wrong!')
      conitue
        
  return train_0, train_1

# %%
slide_id = '091'
train_0, train_1 = generate_train_2(slide_id, 100, ilevel=3, tissue_intensity=0.5)
# Out:
# Read WSI from /content/drive/My Drive/project-adl/slides/tumor_091.tif with width: 61440, height: 53760
# Read tumor mask from /content/drive/My Drive/project-adl/slides/tumor_091_mask.tif
# Slide includes %d levels 8
# Level 0, dimensions: (61440, 53760) downsample factor 1
# Level 1, dimensions: (30720, 26880) downsample factor 2
# Level 2, dimensions: (15360, 13440) downsample factor 4
# Level 3, dimensions: (7680, 6720) downsample factor 8
# Level 4, dimensions: (3840, 3360) downsample factor 16
# Level 5, dimensions: (1920, 1680) downsample factor 32
# Level 6, dimensions: (960, 840) downsample factor 64
# Level 7, dimensions: (480, 420) downsample factor 128
# 8570455 tissue_pixels pixels (29.7 percent of the image)
# [height, width] of sampled patch center: (3865, 4890)
# train_0 add one patch and current have 1 patches!
# [height, width] of sampled patch center: (3817, 2811)
# train_0 add one patch and current have 2 patches!
# [height, width] of sampled patch center: (1623, 1978)
# train_0 add one patch and current have 3 patches!
# [height, width] of sampled patch center: (2499, 4089)
# train_0 add one patch and current have 4 patches!
# [height, width] of sampled patch center: (1801, 5060)
# train_0 add one patch and current have 5 patches!
# [height, width] of sampled patch center: (4110, 3509)
# train_0 add one patch and current have 6 patches!
# [height, width] of sampled patch center: (3993, 4180)
# [height, width] of sampled patch center: (2705, 4463)
# train_0 add one patch and current have 7 patches!
# [height, width] of sampled patch center: (4497, 2548)
# train_0 add one patch and current have 8 patches!
# [height, width] of sampled patch center: (1189, 3612)
# train_0 add one patch and current have 9 patches!
# [height, width] of sampled patch center: (2604, 3731)
# train_0 add one patch and current have 10 patches!
# [height, width] of sampled patch center: (1962, 5413)
# train_0 add one patch and current have 11 patches!
# [height, width] of sampled patch center: (3319, 4082)
# train_0 add one patch and current have 12 patches!
# [height, width] of sampled patch center: (3067, 3791)
# train_0 add one patch and current have 13 patches!
# [height, width] of sampled patch center: (1136, 4687)
# train_0 add one patch and current have 14 patches!
# [height, width] of sampled patch center: (3143, 2974)
# train_0 add one patch and current have 15 patches!
# [height, width] of sampled patch center: (1367, 2625)
# train_0 add one patch and current have 16 patches!
# [height, width] of sampled patch center: (2181, 4511)
# train_0 add one patch and current have 17 patches!
# [height, width] of sampled patch center: (2812, 4389)
# train_0 add one patch and current have 18 patches!
# [height, width] of sampled patch center: (581, 3705)
# train_0 add one patch and current have 19 patches!
# [height, width] of sampled patch center: (1746, 5535)
# train_0 add one patch and current have 20 patches!
# [height, width] of sampled patch center: (3136, 2960)
# train_0 add one patch and current have 21 patches!
# [height, width] of sampled patch center: (1274, 3096)
# train_0 add one patch and current have 22 patches!
# [height, width] of sampled patch center: (3740, 1909)
# train_0 add one patch and current have 23 patches!
# [height, width] of sampled patch center: (4089, 4659)
# [height, width] of sampled patch center: (1983, 2675)
# train_0 add one patch and current have 24 patches!
# [height, width] of sampled patch center: (4000, 4317)
# [height, width] of sampled patch center: (4449, 2630)
# train_0 add one patch and current have 25 patches!
# [height, width] of sampled patch center: (3204, 3919)
# train_0 add one patch and current have 26 patches!
# [height, width] of sampled patch center: (3966, 2907)
# train_0 add one patch and current have 27 patches!
# [height, width] of sampled patch center: (896, 3903)
# train_0 add one patch and current have 28 patches!
# [height, width] of sampled patch center: (2671, 4267)
# train_0 add one patch and current have 29 patches!
# [height, width] of sampled patch center: (3140, 5239)
# train_0 add one patch and current have 30 patches!
# [height, width] of sampled patch center: (2846, 4675)
# train_0 add one patch and current have 31 patches!
# [height, width] of sampled patch center: (1357, 3849)
# train_0 add one patch and current have 32 patches!
# [height, width] of sampled patch center: (1014, 3506)
# train_0 add one patch and current have 33 patches!
# [height, width] of sampled patch center: (2635, 4075)
# train_0 add one patch and current have 34 patches!
# [height, width] of sampled patch center: (1611, 2265)
# train_0 add one patch and current have 35 patches!
# [height, width] of sampled patch center: (2487, 1015)
# train_0 add one patch and current have 36 patches!
# [height, width] of sampled patch center: (2711, 4318)
# train_0 add one patch and current have 37 patches!
# [height, width] of sampled patch center: (1364, 5227)
# train_0 add one patch and current have 38 patches!
# [height, width] of sampled patch center: (3971, 3275)
# train_0 add one patch and current have 39 patches!
# [height, width] of sampled patch center: (1464, 4896)
# train_0 add one patch and current have 40 patches!
# [height, width] of sampled patch center: (2302, 3830)
# train_0 add one patch and current have 41 patches!
# [height, width] of sampled patch center: (1662, 5057)
# train_0 add one patch and current have 42 patches!
# [height, width] of sampled patch center: (2268, 2226)
# train_0 add one patch and current have 43 patches!
# [height, width] of sampled patch center: (2838, 4204)
# train_0 add one patch and current have 44 patches!
# [height, width] of sampled patch center: (2611, 4589)
# train_0 add one patch and current have 45 patches!
# [height, width] of sampled patch center: (1566, 2704)
# train_0 add one patch and current have 46 patches!
# [height, width] of sampled patch center: (2828, 3638)
# train_0 add one patch and current have 47 patches!
# [height, width] of sampled patch center: (2721, 2878)
# train_0 add one patch and current have 48 patches!
# [height, width] of sampled patch center: (2559, 5024)
# train_0 add one patch and current have 49 patches!
# [height, width] of sampled patch center: (1999, 4971)
# train_0 add one patch and current have 50 patches!
# [height, width] of sampled patch center: (4741, 2433)
# train_0 add one patch and current have 51 patches!
# [height, width] of sampled patch center: (3472, 719)
# train_0 add one patch and current have 52 patches!
# [height, width] of sampled patch center: (1686, 4818)
# train_0 add one patch and current have 53 patches!
# [height, width] of sampled patch center: (4208, 3502)
# train_0 add one patch and current have 54 patches!
# [height, width] of sampled patch center: (2246, 3954)
# train_0 add one patch and current have 55 patches!
# [height, width] of sampled patch center: (3969, 4328)
# [height, width] of sampled patch center: (1140, 3554)
# train_0 add one patch and current have 56 patches!
# [height, width] of sampled patch center: (896, 3257)
# train_0 add one patch and current have 57 patches!
# [height, width] of sampled patch center: (2644, 2077)
# train_0 add one patch and current have 58 patches!
# [height, width] of sampled patch center: (1659, 5239)
# train_0 add one patch and current have 59 patches!
# [height, width] of sampled patch center: (3609, 4596)
# [height, width] of sampled patch center: (3101, 5337)
# train_0 add one patch and current have 60 patches!
# [height, width] of sampled patch center: (2409, 1979)
# train_0 add one patch and current have 61 patches!
# [height, width] of sampled patch center: (3210, 2833)
# train_0 add one patch and current have 62 patches!
# [height, width] of sampled patch center: (4184, 2981)
# train_0 add one patch and current have 63 patches!
# [height, width] of sampled patch center: (784, 3948)
# train_0 add one patch and current have 64 patches!
# [height, width] of sampled patch center: (2456, 4337)
# train_0 add one patch and current have 65 patches!
# [height, width] of sampled patch center: (823, 3548)
# train_0 add one patch and current have 66 patches!
# [height, width] of sampled patch center: (814, 3607)
# train_0 add one patch and current have 67 patches!
# [height, width] of sampled patch center: (2273, 4143)
# train_0 add one patch and current have 68 patches!
# [height, width] of sampled patch center: (846, 4333)
# train_0 add one patch and current have 69 patches!
# [height, width] of sampled patch center: (3351, 2656)
# train_0 add one patch and current have 70 patches!
# [height, width] of sampled patch center: (4145, 4417)
# [height, width] of sampled patch center: (2340, 2910)
# train_0 add one patch and current have 71 patches!
# [height, width] of sampled patch center: (4204, 1767)
# train_0 add one patch and current have 72 patches!
# [height, width] of sampled patch center: (1576, 2292)
# train_0 add one patch and current have 73 patches!
# [height, width] of sampled patch center: (3742, 3648)
# train_0 add one patch and current have 74 patches!
# [height, width] of sampled patch center: (3711, 3878)
# train_0 add one patch and current have 75 patches!
# [height, width] of sampled patch center: (4451, 2463)
# train_0 add one patch and current have 76 patches!
# [height, width] of sampled patch center: (1703, 4427)
# train_0 add one patch and current have 77 patches!
# [height, width] of sampled patch center: (2094, 3899)
# train_0 add one patch and current have 78 patches!
# [height, width] of sampled patch center: (2479, 959)
# train_0 add one patch and current have 79 patches!
# [height, width] of sampled patch center: (4156, 1656)
# train_0 add one patch and current have 80 patches!
# [height, width] of sampled patch center: (4559, 2527)
# train_0 add one patch and current have 81 patches!
# [height, width] of sampled patch center: (853, 4245)
# train_0 add one patch and current have 82 patches!
# [height, width] of sampled patch center: (950, 3848)
# train_0 add one patch and current have 83 patches!
# [height, width] of sampled patch center: (482, 4055)
# train_0 add one patch and current have 84 patches!
# [height, width] of sampled patch center: (2156, 4147)
# train_0 add one patch and current have 85 patches!
# [height, width] of sampled patch center: (3209, 4705)
# train_0 add one patch and current have 86 patches!
# [height, width] of sampled patch center: (1441, 3577)
# train_0 add one patch and current have 87 patches!
# [height, width] of sampled patch center: (1386, 2859)
# train_0 add one patch and current have 88 patches!
# [height, width] of sampled patch center: (1813, 4932)
# train_0 add one patch and current have 89 patches!
# [height, width] of sampled patch center: (1296, 3074)
# train_0 add one patch and current have 90 patches!
# [height, width] of sampled patch center: (1624, 2123)
# train_0 add one patch and current have 91 patches!
# [height, width] of sampled patch center: (1966, 5467)
# train_0 add one patch and current have 92 patches!
# [height, width] of sampled patch center: (2068, 3214)
# train_0 add one patch and current have 93 patches!
# [height, width] of sampled patch center: (2573, 4239)
# train_0 add one patch and current have 94 patches!
# [height, width] of sampled patch center: (2011, 3460)
# train_0 add one patch and current have 95 patches!
# [height, width] of sampled patch center: (3197, 1797)
# train_0 add one patch and current have 96 patches!
# [height, width] of sampled patch center: (2087, 1386)
# train_0 add one patch and current have 97 patches!
# [height, width] of sampled patch center: (4656, 2123)
# train_0 add one patch and current have 98 patches!
# [height, width] of sampled patch center: (3816, 3448)
# train_0 add one patch and current have 99 patches!
# [height, width] of sampled patch center: (4246, 3196)
# train_0 add one patch and current have 100 patches!
# train_1 add one patch and current have 1 patches!
# train_1 add one patch and current have 2 patches!
# train_1 add one patch and current have 3 patches!
# train_1 add one patch and current have 4 patches!
# train_1 add one patch and current have 5 patches!
# train_1 add one patch and current have 6 patches!
# train_1 add one patch and current have 7 patches!
# train_1 add one patch and current have 8 patches!
# train_1 add one patch and current have 9 patches!
# train_1 add one patch and current have 10 patches!
# train_1 add one patch and current have 11 patches!
# train_1 add one patch and current have 12 patches!
# train_1 add one patch and current have 13 patches!
# train_1 add one patch and current have 14 patches!
# train_1 add one patch and current have 15 patches!
# train_1 add one patch and current have 16 patches!
# train_1 add one patch and current have 17 patches!
# train_1 add one patch and current have 18 patches!
# train_1 add one patch and current have 19 patches!
# train_1 add one patch and current have 20 patches!
# train_1 add one patch and current have 21 patches!
# train_1 add one patch and current have 22 patches!
# train_1 add one patch and current have 23 patches!
# train_1 add one patch and current have 24 patches!
# train_1 add one patch and current have 25 patches!
# train_1 add one patch and current have 26 patches!
# train_1 add one patch and current have 27 patches!
# train_1 add one patch and current have 28 patches!
# train_1 add one patch and current have 29 patches!
# train_1 add one patch and current have 30 patches!
# train_1 add one patch and current have 31 patches!
# train_1 add one patch and current have 32 patches!
# train_1 add one patch and current have 33 patches!
# train_1 add one patch and current have 34 patches!
# train_1 add one patch and current have 35 patches!
# train_1 add one patch and current have 36 patches!
# train_1 add one patch and current have 37 patches!
# train_1 add one patch and current have 38 patches!
# train_1 add one patch and current have 39 patches!
# train_1 add one patch and current have 40 patches!
# train_1 add one patch and current have 41 patches!
# train_1 add one patch and current have 42 patches!
# train_1 add one patch and current have 43 patches!
# train_1 add one patch and current have 44 patches!
# train_1 add one patch and current have 45 patches!
# train_1 add one patch and current have 46 patches!
# train_1 add one patch and current have 47 patches!
# train_1 add one patch and current have 48 patches!
# train_1 add one patch and current have 49 patches!
# train_1 add one patch and current have 50 patches!
# train_1 add one patch and current have 51 patches!
# train_1 add one patch and current have 52 patches!
# train_1 add one patch and current have 53 patches!
# train_1 add one patch and current have 54 patches!
# train_1 add one patch and current have 55 patches!
# train_1 add one patch and current have 56 patches!
# train_1 add one patch and current have 57 patches!
# train_1 add one patch and current have 58 patches!
# train_1 add one patch and current have 59 patches!
# train_1 add one patch and current have 60 patches!
# train_1 add one patch and current have 61 patches!
# train_1 add one patch and current have 62 patches!
# train_1 add one patch and current have 63 patches!
# train_1 add one patch and current have 64 patches!
# train_1 add one patch and current have 65 patches!
# train_1 add one patch and current have 66 patches!
# train_1 add one patch and current have 67 patches!
# train_1 add one patch and current have 68 patches!
# train_1 add one patch and current have 69 patches!
# train_1 add one patch and current have 70 patches!
# train_1 add one patch and current have 71 patches!
# train_1 add one patch and current have 72 patches!
# train_1 add one patch and current have 73 patches!
# train_1 add one patch and current have 74 patches!
# train_1 add one patch and current have 75 patches!
# train_1 add one patch and current have 76 patches!
# train_1 add one patch and current have 77 patches!
# train_1 add one patch and current have 78 patches!
# train_1 add one patch and current have 79 patches!
# train_1 add one patch and current have 80 patches!
# train_1 add one patch and current have 81 patches!
# train_1 add one patch and current have 82 patches!
# train_1 add one patch and current have 83 patches!
# train_1 add one patch and current have 84 patches!
# train_1 add one patch and current have 85 patches!
# train_1 add one patch and current have 86 patches!
# train_1 add one patch and current have 87 patches!
# train_1 add one patch and current have 88 patches!
# train_1 add one patch and current have 89 patches!
# train_1 add one patch and current have 90 patches!
# train_1 add one patch and current have 91 patches!
# train_1 add one patch and current have 92 patches!
# train_1 add one patch and current have 93 patches!
# train_1 add one patch and current have 94 patches!
# train_1 add one patch and current have 95 patches!
# train_1 add one patch and current have 96 patches!
# train_1 add one patch and current have 97 patches!
# train_1 add one patch and current have 98 patches!
# train_1 add one patch and current have 99 patches!
# train_1 add one patch and current have 100 patches!

# %%
train_dir = 'drive/My Drive/project-adl/train_level%d' %ilevel
if not os.path.exists(train_dir):
  os.mkdir(train_dir)
train_0_dir = os.path.join(train_dir, 'patches0')
train_1_dir = os.path.join(train_dir, 'patches1')
if not os.path.exists(train_0_dir):
  os.mkdir(train_0_dir)
if not os.path.exists(train_1_dir):
  os.mkdir(train_1_dir)
val_dir = 'drive/My Drive/project-adl/val_level%d' %ilevel
if not os.path.exists(val_dir):
  os.mkdir(val_dir)
val_0_dir = os.path.join(val_dir, 'patches0')
val_1_dir = os.path.join(val_dir, 'patches1')
if not os.path.exists(val_0_dir):
  os.mkdir(val_0_dir)
if not os.path.exists(val_1_dir):
  os.mkdir(val_1_dir)

# %%
print(np.shape(train_1))
#plt.figure(figsize=(10,10),dpi=100)
plt.imshow(train_0[5])
from matplotlib.image import imsave
for i in range(int(len(train_0)*0.2)):
  filename = os.path.join(val_0_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_0[i])
  
for i in range(int(len(train_0)*0.2)):
  filename = os.path.join(val_1_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_1[i])
  
for i in range(int(len(train_0)*0.2), len(train_0)):
  filename = os.path.join(train_0_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_0[i])
  
for i in range(int(len(train_0)*0.2), len(train_0)):
  filename = os.path.join(train_1_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_1[i])
# Out:
# (100, 299, 299, 3)

# %% [markdown]
# ## 1.4 Save training patches and images

# %%
ilevel = 3
import shutil
train_dir = 'drive/My Drive/project-adl/train_level%d' %ilevel
if not os.path.exists(train_dir):
  os.mkdir(train_dir)
train_0_dir = os.path.join(train_dir, 'patches0')
train_1_dir = os.path.join(train_dir, 'patches1')
if not os.path.exists(train_0_dir):
  os.mkdir(train_0_dir)
if not os.path.exists(train_1_dir):
  os.mkdir(train_1_dir)

# %%
slide_id
# Out:
# '091'

# %%
print(np.shape(train_1))
#plt.figure(figsize=(10,10),dpi=100)
plt.imshow(train_0[5])
from matplotlib.image import imsave
for i in range(len(train_0)):
  filename = os.path.join(train_0_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_0[i])
  
for i in range(len(train_1)):
  filename = os.path.join(train_1_dir,'tumor_%s_%d.png' %(slide_id, i))
  imsave(filename,train_1[i])
# Out:
# (100, 299, 299, 3)

# %% [markdown]
# # Generate both lev3 and lev4

# %%
def generate_train_ij(slide_id, nclass, ilevel, jlevel, tissue_intensity=0.5):
  slide_path = os.path.join(total_path,'tumor_%s.tif' %slide_id)
  tumor_mask_path = os.path.join(total_path,'tumor_%s_mask.tif' %slide_id)

  slide = open_slide(slide_path)
  print ("Read WSI from %s with width: %d, height: %d" % (slide_path, 
                                                          slide.level_dimensions[0][0], 
                                                          slide.level_dimensions[0][1]))

  tumor_mask = open_slide(tumor_mask_path)
  print ("Read tumor mask from %s" % (tumor_mask_path))

  print("Slide includes %d levels", len(slide.level_dimensions))
  for i in range(len(slide.level_dimensions)):
      print("Level %d, dimensions: %s downsample factor %d" % (i, 
                                                               slide.level_dimensions[i], 
                                                               slide.level_downsamples[i]))
      if i < 8:
        assert tumor_mask.level_dimensions[i][0] == slide.level_dimensions[i][0]
        assert tumor_mask.level_dimensions[i][1] == slide.level_dimensions[i][1]

  # Verify downsampling works as expected
  width, height = slide.level_dimensions[7]
  assert width * slide.level_downsamples[7] == slide.level_dimensions[0][0]
  assert height * slide.level_downsamples[7] == slide.level_dimensions[0][1]

  slide_image = read_slide(slide, 
                           x=int(slide.level_dimensions[ilevel][0]*0.1)*down_factor[ilevel], 
                           y=int(slide.level_dimensions[ilevel][1]*0.1)*down_factor[ilevel], 
                           level=ilevel, 
                           width=int(slide.level_dimensions[ilevel][0]*0.8), 
                           height=int(slide.level_dimensions[ilevel][1]*0.8))

  # Keep only tissue regions
  tissue_pixels = list(find_tissue_pixels(slide_image, intensity=tissue_intensity))
  #print('Dimension of Tissue_pixels:', np.shape(tissue_pixels))
  percent_tissue = len(tissue_pixels) / float(slide_image.shape[0] * slide_image.shape[0]) * 100
  print ("%d tissue_pixels pixels (%.1f percent of the image)" % (len(tissue_pixels), percent_tissue)) 

  train_0_ilevel, train_1_ilevel,  train_0_jlevel, train_1_jlevel= [], [], [], []

  # Generate label 0 class
  while len(train_0_ilevel) < nclass:
    # Random sample a tissue pixel and generate a patch centered in this pixel
    center = tissue_pixels[np.random.choice(np.shape(tissue_pixels)[0])]
    print("[height, width] of sampled patch center:", center)
    # Check whether the 128*128 center pixels have tumor
    ipixels = read_slide(tumor_mask,
                         x = int(center[1]-63)*down_factor[ilevel], 
                         y = int(center[0]-63)*down_factor[ilevel],
                         level = ilevel,
                         width = tumor_check_size,
                         height = tumor_check_size)[:,:,0]
    #plt.imshow(ipixels)
    if not np.any(ipixels) == 1:
      # Expand a 299*299 patch around the center tissue
      ipatch = read_slide(slide, 
                       x=int(center[1]-bound)*down_factor[ilevel], 
                       y=int(center[0]-bound)*down_factor[ilevel], 
                       level=ilevel, 
                       width=input_size, 
                       height=input_size)
      train_0_ilevel.append(ipatch)
      jpatch = read_slide(slide, 
                       x=int(center[1])*down_factor[ilevel]-int(bound)*down_factor[jlevel], 
                       y=int(center[0])*down_factor[ilevel]-int(bound)*down_factor[jlevel], 
                       level=jlevel, 
                       width=input_size, 
                       height=input_size)
      train_0_jlevel.append(jpatch)
      print('train_0 add one patch and current have %d patches!' %len(train_0_ilevel))

  # generate label 1 class, sample only with tumor pixels
  mask_image = read_slide(tumor_mask,
                        x=int(slide.level_dimensions[ilevel][0]*0.1)*down_factor[ilevel], 
                        y=int(slide.level_dimensions[ilevel][1]*0.1)*down_factor[ilevel], 
                        level=ilevel, 
                        width=int(slide.level_dimensions[ilevel][0]*0.8), 
                        height=int(slide.level_dimensions[ilevel][1]*0.8))[:,:,0]
  tumor_id = np.transpose(np.nonzero(mask_image))
  while len(train_1_ilevel) < nclass:
    center = tumor_id[np.random.choice(len(tumor_id))]
    center += [int(slide.level_dimensions[ilevel][1]*0.1), int(slide.level_dimensions[ilevel][0]*0.1)]

    # Check whether the 128*128 center pixels have tumor
    ipixels = read_slide(tumor_mask,
                         x = int(center[1]-63)*down_factor[ilevel], 
                         y = int(center[0]-63)*down_factor[ilevel],
                         level = ilevel,
                         width = tumor_check_size,
                         height = tumor_check_size)[:,:,0]
    if np.any(ipixels)==1: 
      # Expand a 299*299 patch around the center tissue
      ipatch = read_slide(slide, 
                         x=int(center[1]-bound)*down_factor[ilevel], #16 for level=4 
                         y=int(center[0]-bound)*down_factor[ilevel], 
                         level=ilevel, 
                         width=input_size, 
                         height=input_size)
      train_1_ilevel.append(ipatch)
      jpatch = read_slide(slide, 
                         x=int(center[1])*down_factor[ilevel]-int(bound)*down_factor[jlevel], 
                         y=int(center[0])*down_factor[ilevel]-int(bound)*down_factor[jlevel], 
                         level=jlevel, 
                         width=input_size, 
                         height=input_size)
      train_1_jlevel.append(jpatch)
      print('train_1 add one patch and current have %d patches!' %len(train_1_ilevel))
    else:
      print('wrong!')
  return train_0_ilevel, train_1_ilevel, train_0_jlevel, train_1_jlevel

# %%
nclass = 10
ilevel = 3
jlevel = 4
slide_id = '091'
train_0_ilevel, train_1_ilevel, train_0_jlevel, train_1_jlevel=generate_train_ij(slide_id, nclass, 3, 4)
# Out:
# Read WSI from /content/drive/My Drive/project-adl/slides/tumor_091.tif with width: 61440, height: 53760
# Read tumor mask from /content/drive/My Drive/project-adl/slides/tumor_091_mask.tif
# Slide includes %d levels 8
# Level 0, dimensions: (61440, 53760) downsample factor 1
# Level 1, dimensions: (30720, 26880) downsample factor 2
# Level 2, dimensions: (15360, 13440) downsample factor 4
# Level 3, dimensions: (7680, 6720) downsample factor 8
# Level 4, dimensions: (3840, 3360) downsample factor 16
# Level 5, dimensions: (1920, 1680) downsample factor 32
# Level 6, dimensions: (960, 840) downsample factor 64
# Level 7, dimensions: (480, 420) downsample factor 128
# 8570455 tissue_pixels pixels (29.7 percent of the image)
# [height, width] of sampled patch center: (2530, 2941)
# train_0 add one patch and current have 1 patches!
# [height, width] of sampled patch center: (2714, 2480)
# train_0 add one patch and current have 2 patches!
# [height, width] of sampled patch center: (2825, 1302)
# train_0 add one patch and current have 3 patches!
# [height, width] of sampled patch center: (2908, 509)
# train_0 add one patch and current have 4 patches!
# [height, width] of sampled patch center: (3814, 3405)
# train_0 add one patch and current have 5 patches!
# [height, width] of sampled patch center: (1258, 3158)
# train_0 add one patch and current have 6 patches!
# [height, width] of sampled patch center: (2683, 2572)
# train_0 add one patch and current have 7 patches!
# [height, width] of sampled patch center: (2281, 5651)
# train_0 add one patch and current have 8 patches!
# [height, width] of sampled patch center: (3192, 4374)
# train_0 add one patch and current have 9 patches!
# [height, width] of sampled patch center: (3958, 4652)
# [height, width] of sampled patch center: (2443, 2463)
# train_0 add one patch and current have 10 patches!
# train_1 add one patch and current have 1 patches!
# train_1 add one patch and current have 2 patches!
# train_1 add one patch and current have 3 patches!
# train_1 add one patch and current have 4 patches!
# train_1 add one patch and current have 5 patches!
# train_1 add one patch and current have 6 patches!
# train_1 add one patch and current have 7 patches!
# train_1 add one patch and current have 8 patches!
# train_1 add one patch and current have 9 patches!
# train_1 add one patch and current have 10 patches!

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(train_1_ilevel[0])
plt.title('lev 3')
plt.subplot(1,2,2)
plt.imshow(train_1_jlevel[0])
plt.title('lev 4')
# Out:
# Text(0.5, 1.0, 'lev 4')

# %%
plt.figure(figsize=(2,2))
plt.imshow(train_0_ilevel[0])

# %%
plt.figure(figsize=(4,4))
plt.imshow(train_0_jlevel[0])

# %% [markdown]
# # Test 023
# 决定不用了，肿瘤太少了。以后再说
